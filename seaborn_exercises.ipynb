# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pydataset import data

# %%
import seaborn as sns
df = sns.load_dataset('tips')
df.to_clipboard()

# %%
from env import get_db_url


df = sns.load_dataset('tips')
df.to_clipboard()

# %%
url = get_db_url("iris_db")

meas_table = """
SELECT * 
FROM measurements"""

measurements = pd.read_sql(meas_table, url)
measurements.head()
# Out:
#    measurement_id  sepal_length  sepal_width  petal_length  petal_width  \
# 0               1           5.1          3.5           1.4          0.2
# 1               2           4.9          3.0           1.4          0.2
# 2               3           4.7          3.2           1.3          0.2
# 3               4           4.6          3.1           1.5          0.2
# 4               5           5.0          3.6           1.4          0.2
#
#    species_id
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
sns.histplot(measurements.petal_length, kde = True)
plt.show()

# %%
sns.relplot(data = measurements, x = measurements.sepal_length , y = measurements.sepal_width, hue = measurements.species_id)
plt.title('Petal Length and Width Correlation')
# Out:
# Text(0.5, 1.0, 'Petal Length and Width Correlation')

# %%
df.groupby('dataset').describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/n9/2cn6jhrn6y18fntry1wgdn5m0000gp/T/ipykernel_13540/3810142278.py in <module>
# ----> 1 df.groupby('dataset').describe()
#
# NameError: name 'df' is not defined

# %% [markdown]
# #4
# sepal length

# %%
anscombe= sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
anscombe.groupby('dataset')['x','y'].mean().median().stddev()
# Out:
# /var/folders/n9/2cn6jhrn6y18fntry1wgdn5m0000gp/T/ipykernel_13540/1187808565.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   anscombe.groupby('dataset')['x','y'].mean().median().stddev()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/n9/2cn6jhrn6y18fntry1wgdn5m0000gp/T/ipykernel_13540/1187808565.py in <module>
# ----> 1 anscombe.groupby('dataset')['x','y'].mean().median().stddev()
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'stddev'

# %%
sns.histplot(anscombe, kde = True)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.pairplot(anscombe)

# %%
data("InsectSprays",show_doc=True)
insect_sprays= data('InsectSprays')
# Out:
# InsectSprays
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Effectiveness of Insect Sprays
#
# ### Description
#
# The counts of insects in agricultural experimental units treated with
# different insecticides.
#
# ### Usage
#
#     InsectSprays
#
# ### Format
#
# A data frame with 72 observations on 2 variables.
#
# [,1]
#
# count
#
# numeric
#
# Insect count
#
# [,2]
#
# spray
#
# factor
#
# The type of spray
#
# ### Source
#
# Beall, G., (1942) The Transformation of data from entomological field
# experiments, _Biometrika_, **29**, 243–262.
#
# ### References
#
# McNeil, D. (1977) _Interactive Data Analysis_. New York: Wiley.
#
# ### Examples
#
#     require(stats); require(graphics)
#     boxplot(count ~ spray, data = InsectSprays,
#             xlab = "Type of spray", ylab = "Insect count",
#             main = "InsectSprays data", varwidth = TRUE, col = "lightgray")
#     fm1 <- aov(count ~ spray, data = InsectSprays)
# ...

# %%
insect_sprays
# Out:
#     count spray
# 1      10     A
# 2       7     A
# 3      20     A
# 4      14     A
# 5      14     A
# 6      12     A
# 7      10     A
# 8      23     A
# 9      17     A
# 10     20     A
# 11     14     A
# 12     13     A
# 13     11     B
# 14     17     B
# 15     21     B
# 16     11     B
# 17     16     B
# 18     14     B
# 19     17     B
# 20     17     B
# 21     19     B
# 22     21     B
# 23      7     B
# 24     13     B
# 25      0     C
# 26      1     C
# 27      7     C
# 28      2     C
# 29      3     C
# 30      1     C
# 31      2     C
# 32      1     C
# 33      3     C
# 34      0     C
# 35      1     C
# 36      4     C
# 37      3     D
# 38      5     D
# 39     12     D
# 40      6     D
# 41      4     D
# 42      3     D
# 43      5     D
# 44      5     D
# 45      5     D
# 46      5     D
# 47      2     D
# 48      4     D
# 49      3     E
# 50      5     E
# 51      3     E
# 52      5     E
# 53      3     E
# 54      6     E
# ...

# %%
sns.boxplot(data = insect_sprays, x = 'spray', y = 'count')
# Out:
# <AxesSubplot:xlabel='spray', ylabel='count'>

# %%
data("swiss",show_doc=True)
# Out:
# swiss
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Swiss Fertility and Socioeconomic Indicators (1888) Data
#
# ### Description
#
# Standardized fertility measure and socio-economic indicators for each of 47
# French-speaking provinces of Switzerland at about 1888.
#
# ### Usage
#
#     data(swiss)
#
# ### Format
#
# A data frame with 47 observations on 6 variables, each of which is in percent,
# i.e., in [0,100].
#
# [,1] Fertility Ig, "common standardized fertility measure" [,2] Agriculture
# [,3] Examination nation [,4] Education [,5] Catholic [,6] Infant.Mortality
# live births who live less than 1 year.
#
# All variables but 'Fert' give proportions of the population.
#
# ### Source
#
# Project "16P5", pages 549-551 in
#
# Mosteller, F. and Tukey, J. W. (1977) “Data Analysis and Regression: A Second
# Course in Statistics”. Addison-Wesley, Reading Mass.
#
# ...

# %%
swiss = data('swiss')
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %%
swiss['is_catholic']= swiss.Catholic > 50
swiss.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality  is_catholic
# Courtelary                22.2        False
# Delemont                  22.2         True
# Franches-Mnt              20.2         True
# Moutier                   20.3        False
# Neuveville                20.6        False

# %%
sns.boxplot(data = swiss, x = 'is_catholic', y = 'Fertility')
# Out:
# <AxesSubplot:xlabel='is_catholic', ylabel='Fertility'>

# %%
plt.figure(figsize=(12, 10))


plt.subplot(221)
sns.boxplot(data=swiss, x = 'Agriculture', y='Fertility')
plt.title('Agriculture')

plt.subplot(222)
sns.boxplot(data=swiss, x = 'Examination', y='Fertility')
plt.title('Examination')

plt.subplot(223)
sns.boxplot(data=swiss, x = 'Education', y='Fertility')
plt.title('Education')

plt.subplot(224)
sns.boxplot(data=swiss, x = 'Infant.Mortality', y='Fertility')
plt.title('inf')
# Out:
# Text(0.5, 1.0, 'inf')

# %%
sns.pairplot(data = swiss.iloc[:,:-1])

# %%
swiss.corr().Fertility
# Out:
# Fertility           1.000000
# Agriculture         0.353079
# Examination        -0.645883
# Education          -0.663789
# Catholic            0.463685
# Infant.Mortality    0.416556
# is_catholic         0.402813
# Name: Fertility, dtype: float64
