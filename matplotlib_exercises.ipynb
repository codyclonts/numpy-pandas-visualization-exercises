# %%
import matplotlib.pyplot as plt  

#import other libraries 
import numpy as np
import math
from random import randint
import random
import pandas as pd

# %%
#x = np.linspace(-10,10)
x = list(range(-10,10))
y = [(i**2 - i + 2) for i in x]
plt.figure(figsize = (10,8))
plt.plot(x,y, marker = 'o')
plt.grid(True, ls = '--')
plt.annotate("origin",xy=(0,0), xytext= (-3,5) , arrowprops={'facecolor': 'blue'})
plt.title('parabola chart')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
#2
x = range(0,50)
y = [i** .5 for i in x]
plt.figure(figsize = (10,8))

plt.title('Chart 1')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.plot(x,y, color = 'r', label = 'y=√x', marker = '^' )

# %%
#2 cont
x = range(0,50)
y2 = [i**3 for i in x]
plt.figure(figsize = (10,8))

plt.title('Chart 2')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.plot(x,y2, color = 'k',label = 'y=x^3', marker = 'v')

# %%
#2 cont
x = range(0,50)
y3 = [2**i for i in x]
plt.figure(figsize = (10,8))

plt.title('Chart 3')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.plot(x,y3, color = 'b', label = 'y=2^x', marker = '*')

# %%
#2 cont
x = range(0,50)
y4= [(1/(i+1)) for i in x]
plt.figure(figsize = (10,8))

plt.title('Chart 4')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.plot(x,y4, color = 'g', label = 'y=2^x', marker = 'o')

# %%
#2 and 3

x = list(range(0,50))

x1= range(0,10)
y = [x** .5 for x in x]
y2 = [x**3 for x in x]
y3 = [2**x1 for x1 in x1]
y4= [(1/(x+1)) for x in x]


plt.figure(figsize = (12,10))



plt.suptitle('subplots')

plt.subplot(2,2,1)
plt.plot(x,y, color = 'r')
plt.title('y=√x')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid(True, ls = '--')



plt.subplot(2,2,2)
plt.plot(x,y2, color = 'k')
plt.title('y=x^3')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid(True, ls = '--')

plt.subplot(2,2,3)
plt.plot(x1,y3, color = 'b')
plt.title('y=2^x')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid(True, ls = '--')

plt.subplot(2,2,4)
plt.plot(x,y4, color='green')
plt.title('y=2^x')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid(True, ls = '--')


plt.tight_layout()

# %%
#4
x = x = np.linspace(0,10,50)
y = [i** (1/2) for i in x]
y2 = [x**3 for x in x]
y3 = [2**x for x in x]
y4= [(1/(x+1)) for x in x]



plt.figure(figsize=(10,8))

plt.title('4 equations in 1 chart')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.plot(x,y, color = 'r', label = 'y=√x', marker = '^' )
plt.plot(x,y2, color = 'k',label = 'y=x^3', marker = 'v')
plt.plot(x,y3, color = 'b', label = 'y=2^x', marker = '*')
plt.plot(x,y4, color = 'g', label = 'y=2^x', marker = 'o')

plt.legend()
plt.ylim([0, 20])
# Out:
# (0.0, 20.0)
